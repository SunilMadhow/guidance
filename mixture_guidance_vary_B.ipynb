# %%
import random
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
import random
import numpy as np
import torch
import matplotlib.pyplot as plt

seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

from mixture_lower import Mixture
from guided_models import Diffusion, GuidedDiffusion, LastStepDiffusion
from mixture_guidance import MixtureSpecificGuidance
from value_estimator import ValueEstimate
from tv_estimator import tv_bounds_classifier

results = {}

# Diffusion parameters
n = T = 20
t_vals = np.arange(1, n+1)
c, delta = 4, 0.02
inner = delta * (1 + c * np.log(n) / n)**t_vals
alpha_t = 1 - (c * np.log(n) / n) * np.minimum(inner, 1)
alpha_t[0] = 1 - delta
d = 2

# Mixture setup
mu_0 = np.array([[5, 0], [-5, 0]])
var_0 = np.eye(d)
pi_0 = np.array([0.95, 0.05])
pi_0 /= np.sum(pi_0)
dist0 = Mixture(mu_0, var_0, pi_0)
diffusion_unguided = Diffusion(dist0, alpha_t, S=5000)
X_unguided = diffusion_unguided.calc_samples()
unguided_num_steps = T*5000

num_training_trials = 100_000
diffusion = Diffusion(dist0, alpha_t, S=num_training_trials)
X = diffusion.calc_samples()

for B in [1, 3, 5, 9]:
    print(f"\n=== Running for B = {B} ===")
    k = 2
    # def reward_func(x):
    #     x0 = np.asarray(x)[..., 0]
    #     return B / (1 + np.exp(k * (x0 + 8)))
    def reward_func_hard(x):
        x0 = np.asarray(x)[..., 0]
        return np.where(x0 < -7, B, 0)
    L_r = B * k / 4

    # Plot reward function
    x1 = np.linspace(-10, 10, 200)
    x2 = np.linspace(-5, 5, 200)
    X1, X2 = np.meshgrid(x1, x2)
    Z = reward_func_hard(np.stack([X1, X2], axis=-1))
    plt.figure(figsize=(6, 4))
    plt.contourf(X1, X2, Z, levels=50, cmap='viridis')
    plt.colorbar(label='reward_func(x)')
    plt.title(f'Step Function Visualization (B={B})')
    plt.show()

    expr = np.exp(reward_func_hard(X[:, -1, :]))
    plt.plot(expr)
    plt.title(f"Reward Expression (B={B})")
    plt.show()

    # Train value estimator
    val_ensemble = ValueEstimate(X, expr, [128, 500, 500])
    val_ensemble.train()

    # Guided sampling
    guided_per = GuidedDiffusion(
        dist0, alpha_t,
        lambda x, t: np.log(np.clip(val_ensemble.predict(x, t), np.e**(-B), np.e**B)),
        upper_bound=B, temperature=1, S=5000
    )
    X_per = guided_per.calc_samples()

    guided_true = LastStepDiffusion(
        dist0, alpha_t,
        lambda x: np.log(np.clip(reward_func_hard(x), np.e**(-B), np.e**B)),
        upper_bound=B, S=5000
    )
    X_guided_true = guided_true.calc_samples()

    def func(x, val_ensemble):
        x = np.expand_dims(x, axis=0)
        t_arr = np.array([T - 1])
        return np.log(val_ensemble.predict(x, t_arr))

    guided_last = LastStepDiffusion(
        dist0, alpha_t,
        lambda x: func(np.array(x), val_ensemble),
        upper_bound=B, S=5000
    )
    X_guided_last = guided_last.calc_samples()

    guided_msg = MixtureSpecificGuidance(dist0, alpha_t, reward_func_hard, L_r = L_r, value_fn=lambda t, x: (np.log(np.clip(val_ensemble.predict(x, t), np.e**(-B), np.e**B))),   S = 5000, delta = 0.01, use_trace = False)
    X_guided_msg = guided_msg.calc_samples()

    num_steps_msg = guided_msg.num_steps
    num_steps_per = guided_per.num_steps
    num_steps_true = guided_true.num_steps
    num_steps_last = guided_last.num_steps

    # TV distance estimates
    tv_per = tv_bounds_classifier(X[:, -1, :], X_per[:, -1, :])
    tv_true = tv_bounds_classifier(X[:, -1, :], X_guided_true[:, -1, :])
    tv_last = tv_bounds_classifier(X[:, -1, :], X_guided_last[:, -1, :])
    tv_unguided = tv_bounds_classifier(X_unguided[:, -1, :], X_guided_true[:, -1, :])

    results[B] = {
        "tv_per": tv_per,
        "tv_true": tv_true,
        "tv_last": tv_last,
        "tv_unguided": tv_unguided,
        "X_guided_msg": X_guided_msg,
        "X_per": X_per,
        "X_guided_true": X_guided_true,
        "X_guided_last": X_guided_last,
        "X_unguided": X_unguided,
        "num_steps_msg": num_steps_msg,
        "num_steps_per": num_steps_per,
        "num_steps_true": num_steps_true,
        "num_steps_last": num_steps_last,
    }

    # Example: plot histograms for each B
    plt.figure(figsize=(8, 6))
    plt.hist(X[:, -1, 0], bins=100, alpha=0.5, color='green', label='H.P. Guided (per step)')
    plt.hist(X_guided_last[:, -1, 0], bins=100, alpha=0.5, color='blue', label='Guided (last step)')
    plt.hist(X_guided_true[:, -1, 0], bins=100, alpha=0.5, color='orange', label='True optimal')
    plt.xlabel('First Coordinate')
    plt.ylabel('Count')
    plt.title(f'Superimposed Histogram of Final Step Samples (B={B})')
    plt.legend()
    plt.tight_layout()
    plt.show()

# After the loop, you can analyze or plot results for all B values
# for B in results:
#     print(f"\nB = {B}")
#     print("TV (per step):", results[B]["tv_per"]["tv_lb"])
#     print("TV (true):", results[B]["tv_true"]["tv_lb"])
#     print("TV (last step):", results[B]["tv_last"]["tv_lb"])
#     print("TV (unguided):", results[B]["tv_unguided"]["tv_lb"])
# Out:
# Reverse Diffusion Progress: 100%|██████████| 19/19 [00:03<00:00,  5.12it/s]
# Reverse Diffusion Progress: 100%|██████████| 19/19 [00:43<00:00,  2.27s/it]
# === Running for B = 1 ===
# Building ValueEstimate...
# [Epoch 01] avg MSE: 0.0264
# [Epoch 02] avg MSE: 0.0204
# [Epoch 03] avg MSE: 0.0202
# [Epoch 04] avg MSE: 0.0200
# [Epoch 05] avg MSE: 0.0199
# [Epoch 06] avg MSE: 0.0198
# [Epoch 07] avg MSE: 0.0196
# [Epoch 08] avg MSE: 0.0195
# [Epoch 09] avg MSE: 0.0194
# [Epoch 10] avg MSE: 0.0193
# [Epoch 11] avg MSE: 0.0192
# [Epoch 12] avg MSE: 0.0191
# [Epoch 13] avg MSE: 0.0190
# [Epoch 14] avg MSE: 0.0189
# [Epoch 15] avg MSE: 0.0188
# [Epoch 16] avg MSE: 0.0187
# [Epoch 17] avg MSE: 0.0187
# [Epoch 18] avg MSE: 0.0186
# [Epoch 19] avg MSE: 0.0185
# [Epoch 20] avg MSE: 0.0184
# Reverse Diffusion Progress: 100%|██████████| 19/19 [00:13<00:00,  1.39it/s]
# Generating Trajectories: 5441it [00:23, 228.18it/s]
# Generating Trajectories: 5499it [00:10, 537.11it/s]
# Mixture reverse: 100%|██████████| 19/19 [00:21<00:00,  1.14s/it]
# === Running for B = 3 ===
# Building ValueEstimate...
# [Epoch 01] avg MSE: 2.5733
# [Epoch 02] avg MSE: 2.2973
# [Epoch 03] avg MSE: 2.2141
# [Epoch 04] avg MSE: 2.1912
# [Epoch 05] avg MSE: 2.1799
# [Epoch 06] avg MSE: 2.1676
# [Epoch 07] avg MSE: 2.1584
# [Epoch 08] avg MSE: 2.1504
# [Epoch 09] avg MSE: 2.1446
# [Epoch 10] avg MSE: 2.1384
# [Epoch 11] avg MSE: 2.1317
# [Epoch 12] avg MSE: 2.1270
# [Epoch 13] avg MSE: 2.1204
# [Epoch 14] avg MSE: 2.1170
# [Epoch 15] avg MSE: 2.1119
# [Epoch 16] avg MSE: 2.1091
# [Epoch 17] avg MSE: 2.1054
# [Epoch 18] avg MSE: 2.1038
# [Epoch 19] avg MSE: 2.1006
# [Epoch 20] avg MSE: 2.0968
# Reverse Diffusion Progress: 100%|██████████| 19/19 [01:23<00:00,  4.39s/it]
# Generating Trajectories: 5009it [13:54,  6.00it/s]
# Generating Trajectories: 5038it [01:07, 74.39it/s]
# Mixture reverse: 100%|██████████| 19/19 [00:30<00:00,  1.62s/it]
# === Running for B = 5 ===
# Building ValueEstimate...
# [Epoch 01] avg MSE: 140.1973
# [Epoch 02] avg MSE: 133.3563
# [Epoch 03] avg MSE: 130.9678
# [Epoch 04] avg MSE: 129.9082
# [Epoch 05] avg MSE: 129.1209
# [Epoch 06] avg MSE: 128.6466
# [Epoch 07] avg MSE: 128.1322
# [Epoch 08] avg MSE: 127.8090
# [Epoch 09] avg MSE: 127.4437
# [Epoch 10] avg MSE: 127.1843
# [Epoch 11] avg MSE: 126.9116
# [Epoch 12] avg MSE: 126.9297
# [Epoch 13] avg MSE: 126.7208
# [Epoch 14] avg MSE: 126.5520
# [Epoch 15] avg MSE: 126.4955
# [Epoch 16] avg MSE: 126.4883
# [Epoch 17] avg MSE: 126.3279
# [Epoch 18] avg MSE: 126.2796
# [Epoch 19] avg MSE: 126.0828
# [Epoch 20] avg MSE: 125.9317
# Reverse Diffusion Progress: 100%|██████████| 19/19 [05:11<00:00, 16.38s/it]
# Generating Trajectories: 5002it [2:51:51,  2.06s/it]
# Generating Trajectories: 5024it [05:10, 16.18it/s]
# Mixture reverse: 100%|██████████| 19/19 [02:11<00:00,  6.92s/it]
# === Running for B = 9 ===
# Building ValueEstimate...
# [Epoch 01] avg MSE: nan
# [Epoch 02] avg MSE: nan
# [Epoch 03] avg MSE: nan
# [Epoch 04] avg MSE: nan
# [Epoch 05] avg MSE: nan
# [Epoch 06] avg MSE: nan
# [Epoch 07] avg MSE: nan
# [Epoch 08] avg MSE: nan
# [Epoch 09] avg MSE: nan
# [Epoch 10] avg MSE: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 71
#      69 # Train value estimator
#      70 val_ensemble = ValueEstimate(X, expr, [128, 500, 500])
# ---> 71 val_ensemble.train()
#      73 # Guided sampling
#      74 guided_per = GuidedDiffusion(
#      75     dist0, alpha_t,
#      76     lambda x, t: np.log(np.clip(val_ensemble.predict(x, t), np.e**(-B), np.e**B)),
#      77     upper_bound=B, temperature=1, S=5000
#      78 )
#
# File ~/Desktop/Desktop/guidance/value_estimator.py:90, in ValueEstimate.train(self, epochs, verbose)
#      88 for inp, target in self.loader:
#      89     inp, target = inp.to(self.device), target.to(self.device)
# ---> 90     pred = self.forward(inp)            # (...,)
#      91     loss = self.criterion(pred, target)
#      92     self.optimizer.zero_grad()
#
# File ~/Desktop/Desktop/guidance/value_estimator.py:79, in ValueEstimate.forward(self, inp)
#      77 def forward(self, inp):
#      78     # input shape (..., d+1)
# ---> 79     return self.net(inp).squeeze(-1)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/activation.py:133, in ReLU.forward(self, input)
#     132 def forward(self, input: Tensor) -> Tensor:
# --> 133     return F.relu(input, inplace=self.inplace)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/functional.py:1702, in relu(input, inplace)
#    1700     return handle_torch_function(relu, (input,), input, inplace=inplace)
#    1701 if inplace:
# -> 1702     result = torch.relu_(input)
#    1703 else:
#    1704     result = torch.relu(input)
#
# KeyboardInterrupt:

# %%
results
# Out:
# {1: {'tv_per': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.494,
#    'tv_lower_bound': 0.01200000000000001,
#    'tv_plugin': 0.010697827237199597,
#    'kl_star_hat': 0.0005910101019355169,
#    'kl_hat_star': 0.0005799380103554125,
#    'tv_upper_bound': 0.01702847630229159},
#   'tv_true': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.4883333333333333,
#    'tv_lower_bound': 0.023333333333333428,
#    'tv_plugin': 0.023753756722530803,
#    'kl_star_hat': 0.0026297974811779934,
#    'kl_hat_star': 0.0016784398058308906,
#    'tv_upper_bound': 0.02896929241309572},
#   'tv_last': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.4836666666666667,
#    'tv_lower_bound': 0.03266666666666662,
#    'tv_plugin': 0.01679998436785967,
#    'kl_star_hat': 0.001502262372250371,
#    'kl_hat_star': 0.001315218428135603,
#    'tv_upper_bound': 0.025643892334585278},
#   'tv_unguided': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.487,
#    'tv_lower_bound': 0.026000000000000023,
#    'tv_plugin': 0.021135054040784425,
#    'kl_star_hat': 0.002556646340546921,
#    'kl_hat_star': 0.001270699956627285,
#    'tv_upper_bound': 0.025206149613013932},
#   'X_guided_msg': array([[[-0.69711007,  1.04888248],
#           [-0.24044276, -0.21343985],
#           [-0.57642107, -1.59370568],
#           ...,
#           [ 3.81726197,  1.64285667],
#           [ 4.06573911,  1.5417259 ],
#           [ 4.03539772,  1.57856697]],
#
#          [[ 1.33639367, -0.92040723],
#           [ 1.02717036, -0.28785175],
#           [ 1.96946077, -1.05199172],
#           ...,
#           [ 6.12725714, -1.21528725],
#           [ 6.53081265, -1.2652778 ],
#           [ 6.35866448, -1.32359122]],
#
#          [[-0.19279908, -0.67188411],
#           [ 1.2750553 , -1.12450855],
#           [ 1.07618145, -0.93526769],
#           ...,
#           [ 6.83256668,  0.14558311],
#           [ 6.97961385, -0.0565913 ],
#           [ 6.9370785 ,  0.07694511]],
#
#          ...,
#
#          [[ 0.68670661,  0.35771728],
#           [-0.67288111,  0.4194004 ],
#           [-0.34666965, -2.18452928],
#           ...,
#           [ 5.2193062 ,  0.61013205],
#           [ 4.9821344 ,  0.70854231],
#           [ 5.06438522,  1.06374134]],
#
#          [[ 1.57799702, -0.27469001],
#           [ 1.72136174,  1.06286139],
#           [ 1.54298299, -1.02506001],
#           ...,
#           [ 4.55299807, -2.33657355],
#           [ 4.68158749, -2.27647734],
#           [ 4.77307581, -2.26567934]],
#
#          [[-0.50328311, -0.6104374 ],
#           [-2.18453391,  0.37041982],
#           [-0.16294636,  0.77326591],
#           ...,
#           [ 5.88939306,  0.11857478],
#           [ 5.9910027 , -0.07399462],
#           [ 5.92669765, -0.40195836]]]),
#   'X_per': array([[[-1.27662015,  0.84529768],
#           [-2.93973111,  0.8645006 ],
#           [-1.9780021 , -0.06617219],
#           ...,
#           [ 6.03504344, -0.04113854],
#           [ 5.67633509,  0.22020137],
#           [ 5.824732  ,  0.44967809]],
#
#          [[-0.65344488,  2.36178739],
#           [-1.82793726,  1.67611713],
#           [ 0.80647211,  0.92753747],
#           ...,
#           [ 5.89538328,  0.77370397],
#           [ 5.67302127,  0.86706644],
#           [ 5.91769588,  0.91007221]],
#
#          [[-0.50435003, -1.38884719],
#           [ 2.26106748, -1.9166602 ],
#           [ 0.11620428, -2.63884517],
#           ...,
#           [ 4.12003277, -0.46383738],
#           [ 4.06876536, -0.65300957],
#           [ 3.96613429, -0.7019728 ]],
#
#          ...,
#
#          [[-0.26481291,  1.32311045],
#           [-2.06861659,  0.78927731],
#           [-2.85175725,  0.97470148],
#           ...,
#           [ 3.28586291, -0.42394978],
#           [ 3.59400568, -0.30437839],
#           [ 3.55985459, -0.14258373]],
#
#          [[-0.81775981,  0.30141111],
#           [-2.03992145,  0.01979248],
#           [-1.81146727, -2.91104657],
#           ...,
#           [ 5.45228859, -0.30013487],
#           [ 5.67390327, -0.10168209],
#           [ 5.4938623 , -0.15726634]],
#
#          [[ 0.2234862 ,  0.31669875],
#           [-0.0446388 , -0.56498515],
#           [-0.91720044, -0.71214884],
#           ...,
#           [-3.61688705, -1.18182626],
#           [-3.8557474 , -0.91789189],
#           [-4.17084415, -0.94087459]]]),
#   'X_guided_true': array([[[-1.10555919e-01,  1.80190972e-01],
#           [-1.17699963e+00,  2.45374470e+00],
#           [-3.21203617e+00,  4.69217591e+00],
#           ...,
#           [ 5.19383661e+00, -1.19022080e+00],
#           [ 5.33955299e+00, -1.13244101e+00],
#           [ 5.37924672e+00, -1.35797779e+00]],
#
#          [[-7.48740877e-01, -4.33602330e-01],
#           [-1.51588564e+00, -3.89653474e-01],
#           [ 3.67785498e-01, -1.39746107e-01],
#           ...,
#           [ 3.50870555e+00,  1.68999619e+00],
#           [ 3.59566094e+00,  1.55624442e+00],
#           [ 3.60658660e+00,  1.51092321e+00]],
#
#          [[-1.19821528e-01,  7.91811622e-02],
#           [ 1.75307058e+00,  1.39441867e+00],
#           [ 1.54786565e+00,  2.35906877e+00],
#           ...,
#           [-3.62195072e+00,  6.87510397e-01],
#           [-3.80991943e+00,  8.21902526e-01],
#           [-3.85685687e+00,  7.10102802e-01]],
#
#          ...,
#
#          [[-9.14839082e-01,  4.84805187e-01],
#           [-4.08734771e-01,  6.07433249e-01],
#           [-1.04425598e+00,  1.47806462e+00],
#           ...,
#           [ 2.92491253e+00,  6.96262039e-02],
#           [ 3.20889394e+00,  1.24662839e-01],
#           [ 3.13749044e+00,  5.09831030e-02]],
#
#          [[-8.03012228e-01, -1.42622124e+00],
#           [ 5.45601647e-01, -2.37457477e-02],
#           [-9.49708036e-03,  2.32525804e+00],
#           ...,
#           [ 3.36763440e+00,  5.06115800e-01],
#           [ 3.55445603e+00,  6.50848290e-01],
#           [ 3.77357899e+00,  4.45219536e-01]],
#
#          [[ 4.65018361e-03,  6.04033391e-01],
#           [-2.94900567e-01,  2.84696606e-01],
#           [-1.40280070e+00,  2.57336250e+00],
#           ...,
#           [ 6.46255278e+00,  1.32709579e-01],
#           [ 6.44845917e+00, -4.00946647e-02],
#           [ 6.57194508e+00, -2.77371116e-02]]]),
#   'X_guided_last': array([[[ 1.01786284,  0.76113124],
#           [ 1.63071698,  0.75715261],
#           [ 1.82075847,  0.55492951],
#           ...,
#           [ 4.88041042,  2.60814901],
#           [ 5.06484818,  2.59871404],
#           [ 5.14464442,  2.17943076]],
#
#          [[-0.06403446, -1.26872396],
#           [ 0.02068393,  2.38620145],
#           [-0.78708675,  2.89435963],
#           ...,
#           [ 5.42002626,  0.50555747],
#           [ 5.11715016,  0.4688594 ],
#           [ 5.3811007 ,  0.59415185]],
#
#          [[-1.05716277, -1.40309772],
#           [ 1.54225497, -0.56211382],
#           [ 1.24013423, -0.68693739],
#           ...,
#           [ 4.41660319, -0.74597086],
#           [ 4.33340243, -0.72848264],
#           [ 4.30839938, -0.98609908]],
#
#          ...,
#
#          [[ 1.91266618, -0.96704804],
#           [ 0.78774396, -2.31349716],
#           [-1.3787805 , -1.96341125],
#           ...,
#           [ 3.62415109,  0.40240679],
#           [ 3.54720962,  0.20840081],
#           [ 3.65347967,  0.22778138]],
#
#          [[ 0.8172512 , -0.21450127],
#           [ 2.72824698, -2.60582317],
#           [ 1.38182242, -2.16053635],
#           ...,
#           [ 4.454407  ,  0.1163415 ],
#           [ 4.48129623, -0.056308  ],
#           [ 4.59482918, -0.22009542]],
#
#          [[-2.4248944 , -1.65810157],
#           [-0.31524342, -2.37441658],
#           [ 0.79100431,  0.33268409],
#           ...,
#           [ 4.92385247,  0.56641679],
#           [ 5.19633891,  0.79741164],
#           [ 5.0738865 ,  0.846226  ]]]),
#   'X_unguided': array([[[ 0.49671415, -0.1382643 ],
#           [-0.5027476 , -0.46103366],
#           [ 0.12681109,  0.05448862],
#           ...,
#           [ 6.78699574, -0.76594078],
#           [ 6.90726754, -0.43884191],
#           [ 7.07516863, -0.22957967]],
#
#          [[ 0.64768854,  1.52302986],
#           [-0.30798854,  1.09926959],
#           [-1.32062774,  1.40456263],
#           ...,
#           [ 5.44390326, -0.74654443],
#           [ 5.24056217, -0.7676922 ],
#           [ 5.28734769, -0.72646194]],
#
#          [[-0.23415337, -0.23413696],
#           [ 1.32763247, -1.09089191],
#           [-0.9616874 , -1.49046229],
#           ...,
#           [-5.34184553, -0.36536154],
#           [-5.42927956, -0.4473952 ],
#           [-5.57776183, -0.3709271 ]],
#
#          ...,
#
#          [[ 1.19421448,  1.30110206],
#           [ 1.93300158,  1.29791266],
#           [-0.29854256,  0.11597275],
#           ...,
#           [-4.4307725 , -0.46657468],
#           [-4.19574519, -0.31660868],
#           [-4.33793131, -0.49407636]],
#
#          [[-1.99834497, -0.70531672],
#           [ 0.43089475,  0.01600695],
#           [ 2.05833975, -0.60282201],
#           ...,
#           [ 6.12586466, -2.43701756],
#           [ 6.50827089, -2.38294347],
#           [ 6.62366721, -2.33613369]],
#
#          [[ 0.49576557,  0.64438845],
#           [ 2.42106845, -1.57248325],
#           [-0.76111447, -1.27541316],
#           ...,
#           [ 3.99334915,  1.39812117],
#           [ 4.27879073,  1.36630744],
#           [ 4.45802573,  1.20043993]]]),
#   'num_steps_msg': 136265,
#   'num_steps_per': 254360,
#   'num_steps_true': 756756,
#   'num_steps_last': 283679},
#  3: {'tv_per': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.43766666666666665,
#    'tv_lower_bound': 0.1246666666666667,
#    'tv_plugin': 0.10289033039297618,
#    'kl_star_hat': 0.038260845886452066,
#    'kl_hat_star': 0.04679454507154816,
#    'tv_upper_bound': 0.13831277216232069},
#   'tv_true': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.349,
#    'tv_lower_bound': 0.30200000000000005,
#    'tv_plugin': 0.28329432857164216,
#    'kl_star_hat': 0.20936845843301963,
#    'kl_hat_star': 0.2781822332374917,
#    'tv_upper_bound': 0.32354942314352814},
#   'tv_last': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.45099999999999996,
#    'tv_lower_bound': 0.09800000000000009,
#    'tv_plugin': 0.1233725376450812,
#    'kl_star_hat': 0.05654925692138277,
#    'kl_hat_star': 0.06004644703162904,
#    'tv_upper_bound': 0.1681506124303191},
#   'tv_unguided': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.3446666666666667,
#    'tv_lower_bound': 0.31066666666666665,
#    'tv_plugin': 0.28232023983459664,
#    'kl_star_hat': 0.211063421049094,
#    'kl_hat_star': 0.27231872198919815,
#    'tv_upper_bound': 0.32485644602585156},
#   'X_guided_msg': array([[[-0.52667138, -0.41427432],
#           [-1.92279153,  1.73555673],
#           [ 0.81014616,  1.33087965],
#           ...,
#           [ 3.0202654 , -1.72726297],
#           [ 3.09556955, -1.81550102],
#           [ 3.32257899, -2.14828763]],
#
#          [[-1.40735357,  0.69865853],
#           [ 0.35427502, -0.354677  ],
#           [ 0.09863803,  0.7412637 ],
#           ...,
#           [-4.22313552, -3.03534048],
#           [-4.38331523, -3.11118507],
#           [-4.41970746, -2.80252944]],
#
#          [[-1.19832949, -0.9002778 ],
#           [-1.4718885 ,  0.25201343],
#           [-0.67864883,  0.52778633],
#           ...,
#           [ 5.0012707 ,  1.82409395],
#           [ 4.8901377 ,  1.50132988],
#           [ 5.03224946,  1.59701281]],
#
#          ...,
#
#          [[-0.06672052,  0.25139767],
#           [ 0.55999211,  0.52630274],
#           [ 1.50044844,  0.86708269],
#           ...,
#           [ 6.57729351, -0.68815588],
#           [ 6.61836017, -0.57505995],
#           [ 6.64800646, -0.28996484]],
#
#          [[-0.21762178,  0.81075854],
#           [ 1.735284  ,  0.77653998],
#           [ 1.1941912 ,  1.8926118 ],
#           ...,
#           [ 6.15915041,  0.71922992],
#           [ 6.10213259,  0.71401275],
#           [ 5.96942123,  0.65064594]],
#
#          [[ 2.09719775,  0.67679055],
#           [-2.98842359, -0.14869654],
#           [-2.39518357, -0.26068568],
#           ...,
#           [ 5.85881695,  0.92652371],
#           [ 5.91091464,  1.04680089],
#           [ 5.8789485 ,  0.94809918]]]),
#   'X_per': array([[[-0.1600838 , -0.2660395 ],
#           [ 1.16961266,  1.02681657],
#           [-1.17611174,  0.32256437],
#           ...,
#           [-6.57568868,  3.30989885],
#           [-6.55672853,  2.99874367],
#           [-6.7603491 ,  3.0848902 ]],
#
#          [[-0.62582374, -0.86785732],
#           [ 0.62650154, -1.27502647],
#           [ 1.91034413, -1.12691343],
#           ...,
#           [ 4.90350591,  0.07406397],
#           [ 5.04200896,  0.15518127],
#           [ 5.19070021,  0.02684268]],
#
#          [[-0.58694302, -0.15548883],
#           [-1.33966228,  2.08716074],
#           [ 1.16775695,  2.2224599 ],
#           ...,
#           [ 5.16015523, -0.62437303],
#           [ 5.3462749 , -0.81341583],
#           [ 5.39334684, -0.70573957]],
#
#          ...,
#
#          [[ 1.1513227 , -1.30208437],
#           [ 1.28769552, -0.91805684],
#           [ 0.2455516 , -1.51834461],
#           ...,
#           [ 1.99951274,  0.28819402],
#           [ 2.30243547,  0.16021011],
#           [ 2.15220824,  0.03860234]],
#
#          [[ 0.70807624, -0.01456911],
#           [ 2.83214949, -1.03174529],
#           [ 0.86475474,  0.46745625],
#           ...,
#           [ 3.6548957 , -0.43890511],
#           [ 3.47556335, -0.3753345 ],
#           [ 3.50964498, -0.32021459]],
#
#          [[-0.37142179,  0.51242033],
#           [-1.01969537, -2.63935194],
#           [ 0.62948008,  0.18149269],
#           ...,
#           [ 4.09113952,  0.68528687],
#           [ 4.17994131,  0.41300148],
#           [ 4.02769851,  0.42660208]]]),
#   'X_guided_true': array([[[-0.71468468, -0.40177794],
#           [-0.43418195, -0.80627891],
#           [ 0.02014298, -0.86405673],
#           ...,
#           [-7.16063851,  0.7451644 ],
#           [-7.33856677,  0.60395415],
#           [-7.2595847 ,  0.71944276]],
#
#          [[ 1.74079321, -1.76548722],
#           [ 1.62937933, -0.7716359 ],
#           [ 2.05404057, -0.2618907 ],
#           ...,
#           [-6.73316575, -0.68799501],
#           [-7.04172518, -0.86587293],
#           [-7.08402418, -0.66646185]],
#
#          [[-1.2583102 , -0.52791236],
#           [-0.89635324, -1.33351888],
#           [-1.77669601, -0.63398351],
#           ...,
#           [-7.86376798,  1.85444519],
#           [-7.68550679,  1.90075122],
#           [-7.91815961,  1.73553876]],
#
#          ...,
#
#          [[ 0.01082499, -0.47523081],
#           [-1.9260992 ,  0.06102806],
#           [-1.07076856, -2.57260062],
#           ...,
#           [ 5.91311349, -0.98329653],
#           [ 6.00930587, -0.94967614],
#           [ 6.06573066, -0.66067136]],
#
#          [[ 1.45478233, -0.2128528 ],
#           [ 1.30143497, -0.33352607],
#           [-0.20470542, -2.11108453],
#           ...,
#           [ 5.82594446, -0.36792638],
#           [ 5.81667926, -0.44019918],
#           [ 5.79954707, -0.34474354]],
#
#          [[-1.8060778 , -1.41100543],
#           [ 0.34380864, -0.53027353],
#           [-0.61601534,  1.65988866],
#           ...,
#           [ 4.77756829,  2.06022684],
#           [ 4.74342837,  1.83648312],
#           [ 4.82501735,  1.71872918]]]),
#   'X_guided_last': array([[[ 2.409932  , -0.09940351],
#           [ 1.80517702,  0.81606382],
#           [ 0.99687387,  1.67390112],
#           ...,
#           [ 2.97472123,  0.43120897],
#           [ 3.16843063,  0.56146132],
#           [ 3.25558851,  0.58474517]],
#
#          [[ 1.92331145,  0.9086212 ],
#           [ 3.60342193,  0.69326354],
#           [ 4.12737692,  2.92116181],
#           ...,
#           [ 5.89044919,  0.31891748],
#           [ 5.93037634,  0.20310788],
#           [ 5.95799195,  0.48715846]],
#
#          [[ 1.10288271,  0.97126757],
#           [-1.04694385,  1.70954672],
#           [-2.79498707,  3.87977692],
#           ...,
#           [ 3.7222671 ,  0.54620683],
#           [ 3.67069906,  0.45350923],
#           [ 3.79979286,  0.41126718]],
#
#          ...,
#
#          [[-0.8129986 , -0.72144436],
#           [ 0.21108873,  0.12909026],
#           [-0.99973263,  1.80533912],
#           ...,
#           [-7.4411511 , -1.49868284],
#           [-7.40362256, -1.92472445],
#           [-7.46581124, -2.01963172]],
#
#          [[-1.18739191, -2.02603843],
#           [ 0.0163997 , -2.01550808],
#           [ 1.39470346, -0.10351443],
#           ...,
#           [ 3.88627298, -0.75173519],
#           [ 4.16601904, -0.83074366],
#           [ 4.29619016, -0.92280199]],
#
#          [[-0.34522744,  1.48048026],
#           [ 0.22975834, -0.88816834],
#           [ 2.02318693,  3.10331738],
#           ...,
#           [ 4.44789661,  2.30941916],
#           [ 4.44493119,  2.03634864],
#           [ 4.70498843,  1.88236067]]]),
#   'X_unguided': array([[[ 0.49671415, -0.1382643 ],
#           [-0.5027476 , -0.46103366],
#           [ 0.12681109,  0.05448862],
#           ...,
#           [ 6.78699574, -0.76594078],
#           [ 6.90726754, -0.43884191],
#           [ 7.07516863, -0.22957967]],
#
#          [[ 0.64768854,  1.52302986],
#           [-0.30798854,  1.09926959],
#           [-1.32062774,  1.40456263],
#           ...,
#           [ 5.44390326, -0.74654443],
#           [ 5.24056217, -0.7676922 ],
#           [ 5.28734769, -0.72646194]],
#
#          [[-0.23415337, -0.23413696],
#           [ 1.32763247, -1.09089191],
#           [-0.9616874 , -1.49046229],
#           ...,
#           [-5.34184553, -0.36536154],
#           [-5.42927956, -0.4473952 ],
#           [-5.57776183, -0.3709271 ]],
#
#          ...,
#
#          [[ 1.19421448,  1.30110206],
#           [ 1.93300158,  1.29791266],
#           [-0.29854256,  0.11597275],
#           ...,
#           [-4.4307725 , -0.46657468],
#           [-4.19574519, -0.31660868],
#           [-4.33793131, -0.49407636]],
#
#          [[-1.99834497, -0.70531672],
#           [ 0.43089475,  0.01600695],
#           [ 2.05833975, -0.60282201],
#           ...,
#           [ 6.12586466, -2.43701756],
#           [ 6.50827089, -2.38294347],
#           [ 6.62366721, -2.33613369]],
#
#          [[ 0.49576557,  0.64438845],
#           [ 2.42106845, -1.57248325],
#           [-0.76111447, -1.27541316],
#           ...,
#           [ 3.99334915,  1.39812117],
#           [ 4.27879073,  1.36630744],
#           [ 4.45802573,  1.20043993]]]),
#   'num_steps_msg': 534412,
#   'num_steps_per': 1756301,
#   'num_steps_true': 26691827,
#   'num_steps_last': 1804398},
#  5: {'tv_per': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.30033333333333334,
#    'tv_lower_bound': 0.3993333333333333,
#    'tv_plugin': 0.3969303704308085,
#    'kl_star_hat': 0.3886655553205246,
#    'kl_hat_star': 0.5058653313019429,
#    'tv_upper_bound': 0.440831915428389},
#   'tv_true': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.129,
#    'tv_lower_bound': 0.742,
#    'tv_plugin': 0.7643876699456482,
#    'kl_star_hat': 1.647980196217861,
#    'kl_hat_star': 1.6204589449579423,
#    'tv_upper_bound': 0.9001274756827341},
#   'tv_last': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.2696666666666667,
#    'tv_lower_bound': 0.46066666666666656,
#    'tv_plugin': 0.45808710607750497,
#    'kl_star_hat': 0.49497114131850933,
#    'kl_hat_star': 0.6429632641642231,
#    'tv_upper_bound': 0.497479216308837},
#   'tv_unguided': {'n_star': 5000,
#    'n_hat': 5000,
#    'd': 2,
#    'test_error': 0.1263333333333333,
#    'tv_lower_bound': 0.7473333333333334,
#    'tv_plugin': 0.765420743872216,
#    'kl_star_hat': 1.6518758014668005,
#    'kl_hat_star': 1.6020120355836807,
#    'tv_upper_bound': 0.8949893953516099},
#   'X_guided_msg': array([[[ 0.26558846, -0.42020974],
#           [ 0.96183483,  0.57860362],
#           [-0.82513428, -0.0544149 ],
#           ...,
#           [ 3.99269175, -0.1250477 ],
#           [ 4.14499692, -0.03397321],
#           [ 4.26580277, -0.34652473]],
#
#          [[-1.00603744, -1.79848768],
#           [-0.33541412, -1.12508915],
#           [ 0.44610999, -1.69259452],
#           ...,
#           [-9.92803104, -0.62655464],
#           [-9.94395531, -0.68034112],
#           [-9.98281412, -0.65747687]],
#
#          [[ 1.52524901, -0.19833091],
#           [-1.43445783,  0.48627384],
#           [-1.82936139, -0.18461052],
#           ...,
#           [-7.05754611,  0.05479397],
#           [-7.20526908, -0.09599398],
#           [-7.16997879,  0.07039487]],
#
#          ...,
#
#          [[ 1.32507463,  1.49107943],
#           [ 1.01267349, -0.31614879],
#           [ 1.18261674, -1.69843685],
#           ...,
#           [ 4.33255285, -0.93932283],
#           [ 4.43117496, -0.85537633],
#           [ 4.49607623, -0.75357887]],
#
#          [[-0.57783862,  0.8220648 ],
#           [ 0.35789754,  2.13992924],
#           [ 0.92905189,  1.39727069],
#           ...,
#           [-4.73709009,  0.29705416],
#           [-4.73840309,  0.09119052],
#           [-4.6261087 ,  0.17900465]],
#
#          [[-0.35037241,  0.29232581],
#           [ 0.78639362, -1.34375751],
#           [-1.6855022 ,  0.75174567],
#           ...,
#           [ 4.7531665 , -1.48684658],
#           [ 4.83666066, -1.24691149],
#           [ 4.81397538, -1.00586042]]]),
#   'X_per': array([[[-0.36326051,  0.97378633],
#           [ 0.83505342,  1.91828421],
#           [-0.48964152,  1.8262635 ],
#           ...,
#           [ 5.31981484,  0.12468243],
#           [ 5.478607  , -0.07544699],
#           [ 5.90334547, -0.24374904]],
#
#          [[-1.10051454,  1.72145176],
#           [ 2.13831481,  3.42367191],
#           [ 2.27080789,  0.84128872],
#           ...,
#           [ 4.84181581,  2.719855  ],
#           [ 4.86568007,  2.36364512],
#           [ 5.05559641,  2.53257368]],
#
#          [[-1.16712925,  0.14036533],
#           [ 0.70004233, -0.34847564],
#           [ 3.27590949, -0.24751811],
#           ...,
#           [ 4.63302686,  0.99418375],
#           [ 4.78052294,  1.01996489],
#           [ 4.58259313,  0.68228726]],
#
#          ...,
#
#          [[-0.29771472,  1.87698535],
#           [-0.41100715, -0.07650966],
#           [ 0.36918298,  1.25856108],
#           ...,
#           [-7.48236264,  0.31059111],
#           [-7.890435  , -0.04898328],
#           [-8.09074262,  0.04049901]],
#
#          [[ 0.05734907, -0.16673599],
#           [-0.09001926,  1.20611672],
#           [-0.84478192,  2.34502611],
#           ...,
#           [-7.60580582,  0.54673698],
#           [-7.6779512 ,  0.77251756],
#           [-7.88148367,  0.72014842]],
#
#          [[ 0.83411387,  0.78523619],
#           [-0.05674341,  0.52256948],
#           [-1.24084355,  0.32199012],
#           ...,
#           [-7.30099843,  1.85861296],
#           [-7.4274774 ,  1.86717827],
#           [-7.46135568,  1.92349683]]]),
#   'X_guided_true': array([[[ 0.11385843,  0.31601641],
#           [-0.10166496, -0.08289684],
#           [ 0.02047234, -0.3722868 ],
#           ...,
#           [-6.8927065 , -2.0861214 ],
#           [-6.95638665, -2.14972182],
#           [-7.03925424, -2.18922168]],
#
#          [[ 0.46871161,  1.56705637],
#           [-0.05526106, -0.13481093],
#           [-2.44256021,  0.20308595],
#           ...,
#           [-7.38416308,  0.68197804],
#           [-7.41385426,  0.60397088],
#           [-7.33898042,  0.58640499]],
#
#          [[-0.41185863, -1.37706017],
#           [-2.87944344,  1.63261519],
#           [-1.91068526,  2.01382549],
#           ...,
#           [-7.05532037,  1.06950989],
#           [-7.00158141,  1.14849372],
#           [-7.10542436,  1.17377139]],
#
#          ...,
#
#          [[ 1.39433894,  0.68381431],
#           [ 1.29993927,  0.04194844],
#           [ 1.31668672,  0.32487435],
#           ...,
#           [-6.69494577,  0.72598632],
#           [-7.00345958,  0.70344073],
#           [-7.03358747,  0.78955031]],
#
#          [[-0.72625871,  0.1165866 ],
#           [ 0.34867558, -0.01572461],
#           [ 0.34312059,  2.05863324],
#           ...,
#           [-6.99385837, -0.46385707],
#           [-7.35624756, -0.38185358],
#           [-7.35762044, -0.52503295]],
#
#          [[ 0.32243589,  0.75965216],
#           [-0.12232216, -0.55756128],
#           [ 0.07097702, -1.40087968],
#           ...,
#           [-6.97434844, -1.19806935],
#           [-7.25086117, -1.08306867],
#           [-7.3621302 , -1.02750361]]]),
#   'X_guided_last': array([[[-1.92248658, -0.39882305],
#           [-1.61800849, -1.52125543],
#           [-0.50331371, -1.80330137],
#           ...,
#           [-5.42561109, -0.13205582],
#           [-5.30986213, -0.09568755],
#           [-5.29159662, -0.07242413]],
#
#          [[-1.91749936,  0.93870931],
#           [-1.96979037,  1.09502343],
#           [-2.61399643, -0.50248314],
#           ...,
#           [-7.65111378,  2.41667988],
#           [-7.64708439,  2.48538698],
#           [-7.72965673,  2.38859313]],
#
#          [[ 0.45967873,  0.9535131 ],
#           [ 1.50007326,  0.49948737],
#           [ 0.25429332, -0.64498617],
#           ...,
#           [-7.01723745,  1.23707227],
#           [-7.12639737,  1.30087453],
#           [-7.16423896,  1.32994299]],
#
#          ...,
#
#          [[-2.2004415 , -0.74941042],
#           [-0.69780152, -2.04556626],
#           [-2.14958819, -2.23230457],
#           ...,
#           [ 6.32269962, -1.55801287],
#           [ 6.25257582, -1.45842513],
#           [ 6.54062654, -1.59240692]],
#
#          [[-0.50092273,  0.12324682],
#           [-0.97104663, -0.21710545],
#           [-0.99895697,  0.41335911],
#           ...,
#           [ 6.06947908,  0.86909014],
#           [ 6.14851988,  0.94271908],
#           [ 6.25757102,  0.85120959]],
#
#          [[ 0.49044301,  0.51426798],
#           [ 0.64586665, -0.07784235],
#           [ 1.02649285, -1.15188945],
#           ...,
#           [-7.79900903, -0.75272691],
#           [-7.95134157, -0.719624  ],
#           [-7.8791087 , -0.63646279]]]),
#   'X_unguided': array([[[ 0.49671415, -0.1382643 ],
#           [-0.5027476 , -0.46103366],
#           [ 0.12681109,  0.05448862],
#           ...,
#           [ 6.78699574, -0.76594078],
#           [ 6.90726754, -0.43884191],
#           [ 7.07516863, -0.22957967]],
#
#          [[ 0.64768854,  1.52302986],
#           [-0.30798854,  1.09926959],
#           [-1.32062774,  1.40456263],
#           ...,
#           [ 5.44390326, -0.74654443],
#           [ 5.24056217, -0.7676922 ],
#           [ 5.28734769, -0.72646194]],
#
#          [[-0.23415337, -0.23413696],
#           [ 1.32763247, -1.09089191],
#           [-0.9616874 , -1.49046229],
#           ...,
#           [-5.34184553, -0.36536154],
#           [-5.42927956, -0.4473952 ],
#           [-5.57776183, -0.3709271 ]],
#
#          ...,
#
#          [[ 1.19421448,  1.30110206],
#           [ 1.93300158,  1.29791266],
#           [-0.29854256,  0.11597275],
#           ...,
#           [-4.4307725 , -0.46657468],
#           [-4.19574519, -0.31660868],
#           [-4.33793131, -0.49407636]],
#
#          [[-1.99834497, -0.70531672],
#           [ 0.43089475,  0.01600695],
#           [ 2.05833975, -0.60282201],
#           ...,
#           [ 6.12586466, -2.43701756],
#           [ 6.50827089, -2.38294347],
#           [ 6.62366721, -2.33613369]],
#
#          [[ 0.49576557,  0.64438845],
#           [ 2.42106845, -1.57248325],
#           [-0.76111447, -1.27541316],
#           ...,
#           [ 3.99334915,  1.39812117],
#           [ 4.27879073,  1.36630744],
#           [ 4.45802573,  1.20043993]]]),
#   'num_steps_msg': 3740318,
#   'num_steps_per': 7439869,
#   'num_steps_true': 329553082,
#   'num_steps_last': 8452196}}

# %%
import pickle

with open("results_vary_B.pkl", "wb") as f:
    pickle.dump(results, f)
print("Results saved to results_vary_B.pkl")
# Out:
# Results saved to results_vary_B.pkl

# %%
import pickle

with open("results_vary_B.pkl", "rb") as f:
    results_loaded = pickle.load(f)

# Now you can access results as before, e.g.:
print(results_loaded.keys())
print(results_loaded[1].keys())
# Out:
# dict_keys([1, 3, 5])
# dict_keys(['tv_per', 'tv_true', 'tv_last', 'tv_unguided', 'X_guided_msg', 'X_per', 'X_guided_true', 'X_guided_last', 'X_unguided', 'num_steps_msg', 'num_steps_per', 'num_steps_true', 'num_steps_last'])

# %%
fig, axes = plt.subplots(3, 4, figsize=(20, 12))
Bs = sorted(results_loaded.keys())
guided_keys = ["X_per", "X_guided_last", "X_guided_true", "X_guided_msg"]
guided_labels = ["Per Step", "Last Step", "True", "MSG"]
guided_colors = ["green", "purple", "blue", "orange"]

xlim = (-10, 10)
ylim = (-5, 5)

for i, B in enumerate(Bs):
    for j, key in enumerate(guided_keys):
        X_samples = results_loaded[B][key][:, -1, :]
        axes[i, j].scatter(X_samples[:, 0], X_samples[:, 1], s=5, alpha=0.3, color=guided_colors[j])
        axes[i, j].set_title(f"B={B}, {guided_labels[j]}")
        axes[i, j].set_xlabel("x[0]")
        axes[i, j].set_ylabel("x[1]")
        axes[i, j].set_xlim(xlim)
        axes[i, j].set_ylim(ylim)
        axes[i, j].grid(True)

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(3, 4, figsize=(20, 12))
# Set common limits for histograms
hist_xlim = (-10, 10)
hist_ylim = (0, 800)  # Adjust as needed for your data

for i, B in enumerate(Bs):
    for j, key in enumerate(guided_keys):
        X_samples = results_loaded[B][key][:, -1, 0]
        axes[i, j].hist(X_samples, bins=100, alpha=0.7, color=guided_colors[j])
        axes[i, j].set_title(f"B={B}, {guided_labels[j]}")
        axes[i, j].set_xlabel("x[0]")
        axes[i, j].set_ylabel("Count")
        axes[i, j].set_xlim(hist_xlim)
        axes[i, j].set_ylim(hist_ylim)
        axes[i, j].grid(True)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
Bs = sorted(results_loaded.keys())
num_steps_per = [results_loaded[B]["num_steps_per"] for B in Bs]
num_steps_last = [results_loaded[B]["num_steps_last"] for B in Bs]
num_steps_true = [results_loaded[B]["num_steps_true"] for B in Bs]
num_steps_msg = [results_loaded[B]["num_steps_msg"] for B in Bs]

plt.plot(Bs, num_steps_per, marker='o', label='Per Step')
plt.plot(Bs, num_steps_last, marker='o', label='Last Step')
# plt.plot(Bs, num_steps_true, marker='o', label='True')
plt.plot(Bs, num_steps_msg, marker='o', label='MSG')

plt.xlabel('B')
plt.ylabel('Number of Proposals')
plt.title('Number of Proposals Used by Each Model vs B')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

plt.figure(figsize=(10, 6))
Bs = sorted(results_loaded.keys())
num_steps_per = [results_loaded[B]["num_steps_per"] for B in Bs]
num_steps_last = [results_loaded[B]["num_steps_last"] for B in Bs]
num_steps_true = [results_loaded[B]["num_steps_true"] for B in Bs]
num_steps_msg = [results_loaded[B]["num_steps_msg"] for B in Bs]

plt.plot(Bs, num_steps_per, marker='o', label='Per Step')
plt.plot(Bs, num_steps_last, marker='o', label='Last Step')
plt.plot(Bs, num_steps_true, marker='o', label='True')
plt.plot(Bs, num_steps_msg, marker='o', label='MSG')

plt.xlabel('B')
plt.ylabel('Number of Steps')
plt.title('Number of Steps Used by Each Model vs B')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:2353, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2350         bbox_inches = bbox_inches.padded(pad_inches)
#    2352     # call adjust_bbox to save only the given area
# -> 2353     restore_bbox = _tight_bbox.adjust_bbox(
#    2354         self.figure, bbox_inches, self.figure.canvas.fixed_dpi)
#    2356     _bbox_inches_restore = (bbox_inches, restore_bbox)
#    2357 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/_tight_bbox.py:28, in adjust_bbox(fig, bbox_inches, fixed_dpi)
#      26 locator = ax.get_axes_locator()
#      27 if locator is not None:
# ---> 28     ax.apply_aspect(locator(ax, None))
#      29 locator_list.append(locator)
#      30 current_pos = ax.get_position(original=False).frozen()
#
# File ~/anaconda3/lib/python3.11/site-packages/mpl_toolkits/axes_grid1/inset_locator.py:73, in AnchoredLocatorBase.__call__(self, ax, renderer)
#      71 def __call__(self, ax, renderer):
#      72     self.axes = ax
# ---> 73     bbox = self.get_window_extent(renderer)
#      74     px, py = self.get_offset(bbox.width, bbox.height, 0, 0, renderer)
#      75     bbox_canvas = Bbox.from_bounds(px, py, bbox.width, bbox.height)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/offsetbox.py:399, in OffsetBox.get_window_extent(self, renderer)
#     396 def get_window_extent(self, renderer=None):
#     397     # docstring inherited
#     398     if renderer is None:
# --> 399         renderer = self.figure._get_renderer()
#     400     bbox = self.get_bbox(renderer)
#     401     try:  # Some subclasses redefine get_offset to take no args.
#
# AttributeError: 'NoneType' object has no attribute '_get_renderer'

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

plt.figure(figsize=(10, 6))
Bs = sorted(results_loaded.keys())
num_steps_per = [results_loaded[B]["num_steps_per"] for B in Bs]
num_steps_last = [results_loaded[B]["num_steps_last"] for B in Bs]
num_steps_true = [results_loaded[B]["num_steps_true"] for B in Bs]
num_steps_msg = [results_loaded[B]["num_steps_msg"] for B in Bs]

plt.plot(Bs, num_steps_per, marker='o', label='Per Step')
plt.plot(Bs, num_steps_last, marker='o', label='Last Step')
plt.plot(Bs, num_steps_true, marker='o', label='True')
plt.plot(Bs, num_steps_msg, marker='o', label='MSG')

plt.xlabel('B')
plt.ylabel('Number of Steps')
plt.title('Number of Steps Used by Each Model vs B')
plt.legend()
plt.grid(True)
plt.tight_layout()

ax = plt.gca()

# Add inset for B=1
x1_idx = Bs.index(1)
x1 = Bs[x1_idx]
y1 = num_steps_per[x1_idx]
inset1 = inset_axes(ax, width="30%", height="30%", loc='upper left', bbox_to_anchor=(0.05, 0.95, 1, 1), bbox_transform=ax.transAxes)
inset1.plot(Bs, num_steps_per, marker='o', label='Per Step')
inset1.plot(Bs, num_steps_last, marker='o', label='Last Step')
inset1.plot(Bs, num_steps_true, marker='o', label='True')
inset1.plot(Bs, num_steps_msg, marker='o', label='MSG')
inset1.set_xlim(x1-0.5, x1+0.5)
inset1.set_ylim(min(num_steps_per)-10, max(num_steps_per)+10)
inset1.set_xticks([x1])
inset1.set_title('Zoom at B=1')
mark_inset(ax, inset1, loc1=2, loc2=4, fc="none", ec="0.5")

# Add inset for B=5
x5_idx = Bs.index(5)
x5 = Bs[x5_idx]
y5 = num_steps_per[x5_idx]
inset5 = inset_axes(ax, width="30%", height="30%", loc='upper right', bbox_to_anchor=(0.95, 0.95, 1, 1), bbox_transform=ax.transAxes)
inset5.plot(Bs, num_steps_per, marker='o', label='Per Step')
inset5.plot(Bs, num_steps_last, marker='o', label='Last Step')
inset5.plot(Bs, num_steps_true, marker='o', label='True')
inset5.plot(Bs, num_steps_msg, marker='o', label='MSG')
inset5.set_xlim(x5-0.5, x5+0.5)
inset5.set_ylim(min(num_steps_per)-10, max(num_steps_per)+10)
inset5.set_xticks([x5])
inset5.set_title('Zoom at B=5')
mark_inset(ax, inset5, loc1=1, loc2=3, fc="none", ec="0.5")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:2353, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2350         bbox_inches = bbox_inches.padded(pad_inches)
#    2352     # call adjust_bbox to save only the given area
# -> 2353     restore_bbox = _tight_bbox.adjust_bbox(
#    2354         self.figure, bbox_inches, self.figure.canvas.fixed_dpi)
#    2356     _bbox_inches_restore = (bbox_inches, restore_bbox)
#    2357 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/_tight_bbox.py:28, in adjust_bbox(fig, bbox_inches, fixed_dpi)
#      26 locator = ax.get_axes_locator()
#      27 if locator is not None:
# ---> 28     ax.apply_aspect(locator(ax, None))
#      29 locator_list.append(locator)
#      30 current_pos = ax.get_position(original=False).frozen()
#
# File ~/anaconda3/lib/python3.11/site-packages/mpl_toolkits/axes_grid1/inset_locator.py:73, in AnchoredLocatorBase.__call__(self, ax, renderer)
#      71 def __call__(self, ax, renderer):
#      72     self.axes = ax
# ---> 73     bbox = self.get_window_extent(renderer)
#      74     px, py = self.get_offset(bbox.width, bbox.height, 0, 0, renderer)
#      75     bbox_canvas = Bbox.from_bounds(px, py, bbox.width, bbox.height)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/offsetbox.py:399, in OffsetBox.get_window_extent(self, renderer)
#     396 def get_window_extent(self, renderer=None):
#     397     # docstring inherited
#     398     if renderer is None:
# --> 399         renderer = self.figure._get_renderer()
#     400     bbox = self.get_bbox(renderer)
#     401     try:  # Some subclasses redefine get_offset to take no args.
#
# AttributeError: 'NoneType' object has no attribute '_get_renderer'

# %%
results_loaded
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 results_loaded
#
# NameError: name 'results_loaded' is not defined
